# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys 
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import ElementClickInterceptedException
import traceback
import time,uuid


driver = webdriver.Chrome(ChromeDriverManager().install())
driver.maximize_window()
action = ActionChains(driver)
driver.get("https://ciboost-web.tarento.com")
#http://18.196.215.100:9022/login
elements_username = driver.find_element(By.XPATH,"//input[@id='email']")
elements_password = driver.find_element(By.XPATH,"//input[@id='password']")
Login_Button = driver.find_element(By.XPATH,"//button[contains(text(),'Sign In')]")

# login using username and password
elements_username.send_keys("sattu.amarnath+test99@tarento.com")
elements_password.send_keys("Welcome@123")
driver.implicitly_wait(10)
Login_Button.click()
driver.implicitly_wait(10)
element = WebDriverWait(driver, 20).until(
    EC.presence_of_element_located((By.XPATH, "//p[contains(text(),'System admin')]"))
)
element.click()

# create new button
create_new = driver.find_element('xpath','//*[@id="knowledgePacks"]/div/div/div/div[2]/app-button-control/div/div/div/div/div/div/div/div[1]')
create_new.click()

# boost series tag path class= each-name -- //*[@id="knowledgePacks"]/div/div/div/div[2]/app-button-control/div/div/div/div/div[2]/div[1]
driver.implicitly_wait(10)
boost_series = driver.find_element('xpath','//*[@id="knowledgePacks"]/div/div/div/div[2]/app-button-control/div/div/div/div/div[2]/div[1]')
boost_series.click()

# BS templates
driver.implicitly_wait(10)
# template name
temp_name = driver.find_element('xpath','//*[@id="templateName"]')
temp_name.send_keys('boost series name')

driver.implicitly_wait(10)
# description 
desc =driver.find_element('xpath','//*[@id="description"]') 
desc.send_keys('Testing')

driver.implicitly_wait(10)
# next_content button tag path //*[@id="kpForm"]/div/div/form/div[3]/button
next_content = WebDriverWait(driver,200 ).until(
   EC.presence_of_element_located((By.XPATH,'//*[@id="kpForm"]/div/div/form/div[3]/button'))
)
next_content.click()
wait = WebDriverWait(driver, 10)
time.sleep(6)

# BS templates
# ids = '2790'
ids = driver.find_element(By.XPATH,'//app-tab-selection')
ids = ids.get_attribute('id')
print(ids)

# create new module 
create_module = driver.find_element(By.XPATH,'//*[@id='+ids+']/div/section[2]/app-content/div[1]/div/div[1]/div[1]/div/div/button')
create_module.click()
time.sleep(6)

### go for the value in module1 button
module_name = driver.find_element(By.XPATH,'//*[@id="cdk-drop-list-0"]/div/div/input')
module_name.click()
time.sleep(6)

##### enter value in the input field and press enter
xpath_value ='//*[@id="cdk-drop-list-0"]/div/div/input'
wait.until(EC.presence_of_element_located((By.XPATH, xpath_value))).send_keys('m1')
time.sleep(6)
wait.until(EC.presence_of_element_located((By.XPATH, xpath_value))).send_keys(Keys.RETURN)
time.sleep(6)

# create chapter
xpath_value_chapter_click ='//*[@id='+ids+']/div/section[2]/app-content/div[1]/div/div[2]/div[1]/div/div/button'
wait.until(EC.presence_of_element_located((By.XPATH, xpath_value_chapter_click))).send_keys(Keys.RETURN)

### input fields for the chapter and press enter
xpath_chapter_input = '//*[@id="cdk-drop-list-1"]/div/div/input'
wait.until(EC.presence_of_element_located((By.XPATH, xpath_chapter_input))).send_keys('c11')
time.sleep(6)
wait.until(EC.presence_of_element_located((By.XPATH, xpath_chapter_input))).send_keys(Keys.RETURN)
time.sleep(6)

# create section
section = driver.find_element(By.XPATH,'//*[@id='+ids+']/div/section[2]/app-content/div[1]/div/div[3]/div[1]/div/div/button')
section.click()
time.sleep(5)

### input field for section and press enter
xpath_section_input = '//*[@id="createsection"]'
wait.until(EC.presence_of_element_located((By.XPATH, xpath_section_input))).send_keys('s11')
time.sleep(6)
wait.until(EC.presence_of_element_located((By.XPATH, xpath_section_input))).send_keys(Keys.RETURN)
time.sleep(6)

# click() to move to next page (edit) on the input field of section to
wait.until(EC.element_to_be_clickable((By.XPATH, '//span[.="s11"]'))).click()
time.sleep(6)

## click on plus icon
text = driver.find_element(By.XPATH,'/html/body/app-root/app-common-header/app-section/div[3]/div/div/span[2]')
text.click()
time.sleep(6)

# click on text image 
text_image = driver.find_element(By.XPATH,'/html/body/app-root/app-common-header/app-section/div[1]/app-tab-selection/div/section/div/button[1]')
text_image.click()
time.sleep(6)

##### enter value in the text input field
xpath_value ='//*[@id="textEditor"]/p-editor/div/div[3]/div[1]'
wait.until(EC.presence_of_element_located((By.XPATH, xpath_value))).send_keys('what are you doing')
time.sleep(6)
wait.until(EC.presence_of_element_located((By.XPATH, xpath_value))).send_keys(Keys.RETURN)
time.sleep(6)

# clicking on done after entering the input field
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
element = driver.find_element(By.CSS_SELECTOR, ".btn-success")

#clicking on save after adding the content
wait.until(EC.presence_of_element_located((By.XPATH,'//*[@id="textEditor"]/div[1]/button[2]')))
time.sleep(5)
element = driver.find_element(By.XPATH, "//*[@id='textEditor']/div[1]/button[2]")
driver.execute_script("return arguments[0].scrollIntoView(true);", element)
element.click()
time.sleep(6)

#click on plus icon to upload image
text = driver.find_element(By.XPATH,'/html/body/app-root/app-common-header/app-section/div[3]/div/div/span[2]')
text.click()


#click on image upload sign
image_upload = driver.find_element(By.XPATH,'/html/body/app-root/app-common-header/app-section/div[1]/app-tab-selection/div/section/div/button[2]/label/span')
image_upload.click()
time.sleep(5)

#click on add image from system
img_inp = driver.find_element(By.CSS_SELECTOR,'#fileuploaded')
img_inp.send_keys(r"C:\Users\Sattu Amarnath\Downloads\Screenshot 2023-01-16 at 6.33.18 PM.png")
time.sleep(10)


#click on done button
img_done = driver.find_element(By.XPATH,'//button[.="Done "]')
driver.execute_script('arguments[0].click()',img_done)
time.sleep(10)

#click on save button
button_save = driver.find_element(By.XPATH,'//*[@id="kp-header"]/a')
button_save.click()
time.sleep(6)

# create section
#section = driver.find_element(By.XPATH,'/html/body/app-root/app-common-header/app-manage-knowledgepack/div/app-tab-selection/div/section[2]/app-content/div[1]/div/div[3]/div[1]/div/div/button/img')
#section.click()
#time.sleep(5)

### input field for section and press enter
#xpath_section_input = '//*[@id="createsection"]'
#wait.until(EC.presence_of_element_located((By.XPATH, xpath_section_input))).send_keys('m1')
#time.sleep(6)
#wait.until(EC.presence_of_element_located((By.XPATH, xpath_section_input))).send_keys(Keys.RETURN)
#time.sleep(6)

# click on m1 section
#wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/app-root/app-common-header/app-manage-knowledgepack/div/app-tab-selection/div/section[2]/app-content/div[1]/div/div[3]/div[2]/div/div/div[2]/div/span[2]'))).click()
#time.sleep(6)

#click on plus icon to upload video
#text_upload = driver.find_element(By.XPATH,'/html/body/app-root/app-common-header/app-section/div[3]/div/div/span[2]')
#text_upload.click()
#time.sleep(5)


#click on video upload sign
#video_upload = driver.find_element(By.XPATH,'/html/body/app-root/app-common-header/app-section/div[1]/app-tab-selection/div/section/div/button[4]')
#video_upload.click()
#time.sleep(5)

#click on add video from system
#video_inp = driver.find_element(By.CSS_SELECTOR,'#fileuploaded')
#video_inp.send_keys(r"C:\Users\Sattu Amarnath\Downloads\WIN_20220930_12_20_26_Pro.mp4")
#time.sleep(10)

#click on plus icon to upload video
#text_upload = driver.find_element(By.XPATH,'/html/body/app-root/app-common-header/app-section/div[3]/div/div/span[2]')
#text_upload.click()
#time.sleep(5)

#click on save button
#button_save = driver.find_element(By.XPATH,'//*[@id="kp-header"]/a')
#button_save.click()
#time.sleep(6)

#click on organization 
driver.implicitly_wait(10) 
element=driver.find_element(By.XPATH,"//a[contains(text(),'Organizations')]")
element.click()
time.sleep(5)


# click on create new org
create_new = driver.find_element(By.XPATH,'//*[@id="organizations"]/div/div/div/div[2]/app-button-control/div/div/div/div/div/div/div/div[2]/div')
create_new.click()
time.sleep(5)

### input field for org name
xpath_section_input = '//*[@id="name"]'
org_name = str(uuid.uuid4()) + ' org'
print(f'{org_name=}')
wait.until(EC.presence_of_element_located((By.XPATH, xpath_section_input))).send_keys(org_name)
time.sleep(6)
wait.until(EC.presence_of_element_located((By.XPATH, xpath_section_input))).send_keys(Keys.RETURN)
time.sleep(6)

### input field for org description
xpath_section_input = '//*[@id="desc"]'
wait.until(EC.presence_of_element_located((By.XPATH, xpath_section_input))).send_keys('Testing')
time.sleep(6)
wait.until(EC.presence_of_element_located((By.XPATH, xpath_section_input))).send_keys(Keys.RETURN)
time.sleep(6)

### input field for org contact person
xpath_section_input = '//*[@id="contactPerson"]'
wait.until(EC.presence_of_element_located((By.XPATH, xpath_section_input))).send_keys('sattu')
time.sleep(6)
wait.until(EC.presence_of_element_located((By.XPATH, xpath_section_input))).send_keys(Keys.RETURN)
time.sleep(6)

### input field for org contact information
xpath_section_input = '//*[@id="contactInfo"]'
wait.until(EC.presence_of_element_located((By.XPATH, xpath_section_input))).send_keys('svzuuuulzmiu.am@tarento.com')
time.sleep(6)
wait.until(EC.presence_of_element_located((By.XPATH, xpath_section_input))).send_keys(Keys.RETURN)
time.sleep(6)

#click on teams in org dashboard
create_new = driver.find_element('xpath','/html/body/app-root/app-common-header/app-orgpreview/div/section[2]/div/div/div[1]/div/div[3]/div/div/div/div[2]/div/div/div[1]/p')
create_new.click()

# click on create new team
create_new = driver.find_element('xpath','//*[@id="organizations"]/div/div/div/div[2]/app-button-control/div/div/div/div/div/div/div/div[2]/div')
create_new.click()

### input field for create team name
xpath_section_input = '//*[@id="createteam"]/div/div[2]/div/form/div[1]/input'
wait.until(EC.presence_of_element_located((By.XPATH, xpath_section_input))).send_keys('nowttwe team')
time.sleep(6)
wait.until(EC.presence_of_element_located((By.XPATH, xpath_section_input))).send_keys(Keys.RETURN)
time.sleep(6)

# click on save and proceed
#create_new = driver.find_element(By.XPATH,'//*[@id="createteam"]/div/div[2]/div/form/div[2]/button')
#create_new.click()

# click on created team name
driver.implicitly_wait(10) 
element=driver.find_elements(By.CSS_SELECTOR,'.container.p-1')[0]
element.click()
time.sleep(5)

#click on import boost series template
boostseries_new = driver.find_element(By.XPATH,'//*[@id="teamdetails"]/app-tab-selection/div/div/div[1]/div/div[2]/button')
boostseries_new.click()

#click on master template
mastertemplate_new = driver.find_element(By.XPATH,'//*[@id="importkPackModal"]/div/div/div[2]/ul/li[1]')
mastertemplate_new.click()

#selecting one boost series
boostseries_new = driver.find_element(By.XPATH,'//*[@id="importkPackModal"]/div/div/div[2]/div/div/div[1]/div/p[2]')
boostseries_new.click()

#click on add boost series
addboostseries_new = driver.find_element(By.XPATH,'//*[@id="importkPackModal"]/div/div/div[3]/button[2]')
addboostseries_new.click()
time.sleep(15)

# click on members inside team
teammember_new = driver.find_element(By.XPATH,'//*[@id="tabHeader"]/li[3]/a')
teammember_new.click()

# click on add existing user
user_new = driver.find_element(By.XPATH,'//*[@id="teamdetails"]/app-tab-selection/div/div/div/div/div[2]/div/div/div[1]/button')
user_new.click()

# selecting user
user_new = driver.find_element(By.XPATH,'//*[@id="allUser"]/app-tab-selection/div/div[2]/div[8]/div/div/div[2]/div[1]/div/div')
user_new.click()

# click on done button
done_new = driver.find_element(By.XPATH,'//*[@id="org-header"]/nav/ol/li[2]/a')
done_new.click()

#userview
#click on profile image
click_new = driver.find_element(By.CSS_SELECTOR,'#navbarDropdownMenuLink')
click_new.click()
time.sleep(1)

#clicking on selecting to switch to userview
click_new = driver.find_element(By.XPATH,'//*[@id="navbarSupportedContent"]/ul/li/div/a[1]')
click_new.click()
time.sleep(6)

#click on choose organization
click_new = driver.find_element(By.XPATH,'//*[@id="orgdata1"]')
click_new.click()
time.sleep(5)

#click on notes icon
click_new = driver.find_element(By.XPATH,'/html/body/app-root/app-home/div[1]/div/div/app-header/header/nav/div/ul/li[1]/a/img')
click_new.click()
time.sleep(6)

#click on Add notes
click_new = driver.find_element(By.XPATH,'/html/body/app-root/app-home/div[1]/div/div/app-header/header/nav/div/ul/li[1]/span/div/button')
click_new.click()
time.sleep(6)

### input field for Add notes Title
xpath_value ='//*[@id="newNoteinput"]'
wait.until(EC.presence_of_element_located((By.XPATH, xpath_value))).send_keys("module-1")
time.sleep(6)
wait.until(EC.presence_of_element_located((By.XPATH, xpath_value))).send_keys(Keys.RETURN)
time.sleep(6)

### input field for Add notes Description
xpath_value ='//*[@id="newNoteTxtArea"]'
wait.until(EC.presence_of_element_located((By.XPATH, xpath_value))).send_keys('module-1')
time.sleep(6)
wait.until(EC.presence_of_element_located((By.XPATH, xpath_value))).send_keys(Keys.RETURN)
time.sleep(6)

#click on Add note
click_new = driver.find_element(By.XPATH,'/html/body/app-root/app-home/div[1]/div/div/app-header/header/div[1]/div/form/div/div[3]/button[2]')
click_new.click()
time.sleep(6)

#click on view more
click_new = driver.find_element(By.XPATH,'/html/body/app-root/app-home/div[1]/div/div/div/div/div[1]/div[2]/div/div/div[1]/div/div[2]/div/div/div[1]')
click_new.click()
time.sleep(5)

#selecting boost series inside team
click_new = driver.find_element(By.XPATH,'/html/body/app-root/app-teamdashboard/div[1]/div/div[3]/div[1]/div/div[1]/div/div[2]/div/div[1]/p')
click_new.click()
time.sleep(5)

#clicking on unlocking the boostseries
#click_new = driver.find_element(By.XPATH,'//*[@id="sessionDetails"]/div/div[2]/div[1]/div[2]/ul/li[1]/div[2]/i')
#click_new.click()
#time.sleep(6)

#clicking on yes to unlock the boost series
#click_new = driver.find_element(By.XPATH,'//*[@id="unlockConfirmModal"]/div/div/div[2]/button[2]')
#click_new.click()
#time.sleep(6)

#click on chapters
click_new = driver.find_element(By.XPATH,'//*[@id="sessionDetails"]/div/div[2]/div[1]/div[2]/ul/li/div/div')
click_new.click()
time.sleep(6)

#click on chapter one
#click_new = driver.find_element(By.XPATH,'//*[@id="sessionDetails"]/div/div[2]/div[1]/div[2]/ul/li[1]/div[1]/div')
#click_new.click()
#time.sleep(6)

#click on next button
click_new = driver.find_element(By.XPATH,'//*[@id="boostSessionCarousel"]/div/div[2]/div[1]/div[3]/a/div[2]')
click_new.click()
time.sleep(6)

#click on next button
click_new = driver.find_element(By.XPATH,'//*[@id="boostSessionCarousel"]/div/div[2]/div[1]/div[3]/a/div[2]')
click_new.click()
time.sleep(6)

#click on next button
click_new = driver.find_element(By.XPATH,'//*[@id="boostSessionCarousel"]/div/div[2]/div[1]/div[3]/a/div[2]')
click_new.click()
time.sleep(6)

#click on complete button
click_new = driver.find_element(By.XPATH,'//*[@id="boostSessionCarousel"]/div/div[2]/div[1]/div[3]/a/div/div/div')
click_new.click()
time.sleep(6)

print('done')
driver.quit()
